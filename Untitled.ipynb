# %%
# %autosave 1
# Out:
# Autosaving every 1 seconds

# %%
import requests

# %%
url = 'http://127.0.0.1:9696/predict'

# %%
client ={
       "customerid" :15719508,
        "surname" : "davis",
        "creditscore" :528,
        "geography" :  "france",
        "gender"     :  "male",
        "age"         :  31,
        "tenure"       : 6,
        "balance"       : 102016.72,
        "numofproducts"  :   2,
        "hascrcard"       :   "no",
        "isactivemember"   : "no",
        "estimatedsalary"   :  80181.12,
        "complain"            : "no",
        "satisfaction_score"   :  3,
        "card_type"  :  'gold',
        "point_earned"           : 264
}

# %%
Response = requests.post(url,json= client).json()
Response
# Out:
# {'exit_probability': 0.0008944543828264759, 'will_exit': False}

# %%
if response['exit'] == True:
    print("Send promotional email to avoid Exit.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 if response['exit'] == True:
#       2     print("Send promotional email to avoid Exit.")
#
# NameError: name 'response' is not defined
